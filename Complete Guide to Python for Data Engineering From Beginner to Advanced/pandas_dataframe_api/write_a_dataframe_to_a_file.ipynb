# %%
import pandas as pd 

import matplotlib as plt

# %%
data = {'Topping' : ['Pepperoni', 'Mushroom', 'Olive', 'Sausage'],
        'Count' : [25, 15, 10, 20]}

df = pd.DataFrame(data)

# %%
sum = df['Count'].sum()
print(sum)
# Out:
# 70
